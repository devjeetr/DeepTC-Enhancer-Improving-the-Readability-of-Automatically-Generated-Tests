# %%
import sys
sys.path.append("../")
from utilities.data import BPEVocabulary
from models.Transformer.TransformerLightning import TransformerLightning
import torch
import os
from utilities.C2SDataSet import C2SDataSet
from argparse import Namespace
from pathlib import Path
from torch.utils.data import DataLoader
from apex import amp

# %%
from utilities.data import BPEVocabulary
from models.Transformer.TransformerLightning import TransformerLightning
import torch
from utilities.C2SDataSet import C2SDataSet
from argparse import Namespace
from torch.utils.data import DataLoader
from torch.nn import functional as F

def create_dataset_from_hparams(filepath, hparams, vocabulary, variables=False):
    return C2SDataSet(
        filepath,
        hparams.max_contexts,
        vocabulary,
        hparams.subtoken_len,
        hparams.ast_len,
        hparams.target_len,
        shuffle=True,
        variable_only_filter=variables,
        line_cache=None,
    )

device = torch.device("cuda")
def batch_to_cuda(batch):
    label, input_tensors = batch
    label = label.cuda()
    input_tensors = (t.to(device) for t in input_tensors)
    
    return (label, input_tensors)


def run_inference(filepath, model, hparams, variables=False):
    dataset = create_dataset_from_hparams(filepath, hparams, model.vocabulary, variables=variables)
    dataloader = DataLoader(dataset, batch_size=1)

    for batch in dataloader:

        batch = batch_to_cuda(batch)

        predictions, raw = model.predict(batch)
        predictions = predictions.tolist()
        
        labels = batch[0].tolist()

        prediction = model.vocabulary.decode_target(predictions[0])
        label = model.vocabulary.decode_target(labels[0])

        print(f"{label} -> {prediction}")


def load_model(path, model_name, root = None):
    if not root:
        root = path
        
    checkpoint = torch.load(os.path.join(path, model_name))
    hparams = Namespace(**checkpoint["hparams"])
    # update vocabulary location
    for k, v in hparams.__dict__.items():
        if isinstance(v, str) and (v.endswith("-vocab.json") or v.endswith("-merges.txt") or os.path.basename(v) == "node_dict.pkl"):
            setattr(hparams, k, os.path.join(root, os.path.basename(v)))
#             print(os.path.join(path, os.path.basename(v)))
            
    model = TransformerLightning(hparams)
    model.load_state_dict(checkpoint["state_dict"])

    model.eval()
    model.cuda()
    return model, hparams

# %%
def create_dataset_from_hparams(filepath, hparams, vocabulary):
    return C2SDataSet(
        filepath,
        hparams.max_contexts,
        vocabulary,
        hparams.subtoken_len,
        hparams.ast_len,
        hparams.target_len,
        shuffle=True,
        variable_only_filter=True,
        line_cache=None,
    )

def run_inference(filepath, model, hparams):
    dataset = create_dataset_from_hparams(filepath, hparams, model.vocabulary)
    dataloader = DataLoader(dataset, batch_size=1)

    for batch in dataloader:

        (
            labels,
            (start, end, path, masks, start_lengths, end_lengths, ast_path_lengths),
        ) = batch
        labels = labels.cuda()
        start = start.cuda()
        end = end.cuda()
        path = path.cuda()
        masks = masks.cuda()
        start_lengths = start_lengths.cuda()
        end_lengths = end_lengths.cuda()
        ast_path_lengths = ast_path_lengths.cuda()
        batch = (
            labels,
            (start, end, path, masks, start_lengths, end_lengths, ast_path_lengths),
        )

        predictions, raw = model.predict(batch)
        # print()
        # print(f"raw: {raw.shape}")
        # print_topk(raw, labels, index_to_target)
        predictions = predictions.tolist()
        labels = labels.tolist()


        prediction = model.vocabulary.decode_target(predictions[0])

        label = model.vocabulary.decode_target(labels[0])
        # print(predictions[0])
        # print(label[0])

        print(prediction)
        print(label)

# %%
# input: B x * x ... x *
# dim: 0 <= scalar
# index: M
def batched_index_select(input, dim, index):
    views = [1 if i != dim else -1 for i in range(len(input.shape))]
    expanse = list(input.shape)
    expanse[dim] = -1
    index = index.view(views).expand(expanse)
    # making the first dim of output be B
    return torch.cat(torch.chunk(torch.gather(input, dim, index), chunks=index.shape[0], dim=dim), dim=0)

def incremental_decode(model, batch, current_decoder_output):
    with torch.no_grad():
        (start, end, path, masks, start_lengths, end_lengths, ast_path_lengths) = batch

    return model(start,
                    end,
                    path,
                    start_lengths,
                    end_lengths,
                    ast_path_lengths,
                    masks, current_decoder_output)

from einops import rearrange

def beam_search(model, batch, beam_size=3):
    label, _ = batch
    batch_size = label.shape[0]
    max_seq_len = label.shape[-1]
    batch = [item.cuda() for item in batch[1]]

    sos_idx = model.vocabulary.encode_target(model.vocabulary.SOS_TOKEN)
    eos_idx = model.vocabulary.encode_target(model.vocabulary.EOS_TOKEN)

    current_decoder_outputs = torch.tensor([sos_idx] * batch_size).reshape(batch_size, 1, 1).long().cuda()
    current_decoder_scores = torch.zeros(batch_size, 1).cuda()
    # current_decoder_output: (batch_size, beam_size, seq_len)

    print(f"current_decoder_outputs: {current_decoder_outputs.shape}")
    while current_decoder_outputs.shape[-1] < max_seq_len:
        # print()
        # print(f"original batch size: {batch[0].shape}")
        # print(f"current_decoder_outputs: {current_decoder_outputs.shape}")
        # current_decoder_output: batch_size, current_beam_size, seq_len
        current_beam_size = current_decoder_outputs.shape[1]
        seq_len = current_decoder_outputs.shape[-1]
        # print(current_beam_size)
        current_decoder_outputs = current_decoder_outputs.reshape(-1, current_decoder_outputs.shape[-1])
        #current_decoder_output: batch_size * current_beam_size, seq_len
        current_batch = list(
            map(lambda x: x.repeat_interleave(current_beam_size, dim=0), batch)
        )
        current_increment = incremental_decode(
            model, 
            current_batch, 
            current_decoder_outputs)

        predictions = F.log_softmax(current_increment, dim=2)[:, -1, :]
        predictions = predictions.reshape(batch_size, -1)
        # print(f"{predictions.shape}")

        topk = predictions.topk(beam_size, dim=-1)
        topk_scores = topk.values.reshape(-1, 1)
        topk_predictions = topk.indices.reshape(-1, 1)

        # print(f"topk_scores: {topk_scores.shape}")

        current_decoder_scores_repeated = current_decoder_scores
        if current_decoder_scores.shape[0] < topk_scores.shape[0]:
            current_decoder_scores_repeated = current_decoder_scores.repeat_interleave(beam_size).cuda()

        candidate_scores = current_decoder_scores_repeated.reshape(-1) + topk_scores.reshape(-1)
        # print(f"candidate: {candidate_scores.shape}")
        candidate_scores = candidate_scores.reshape(-1, 1)

        current_decoder_outputs_repeated = current_decoder_outputs
        if current_decoder_outputs.shape[0] < topk_predictions.shape[0]:
            current_decoder_outputs_repeated = current_decoder_outputs.repeat_interleave(beam_size, dim=0).cuda()

        candidate_outputs = torch.cat([current_decoder_outputs_repeated, topk_predictions], dim=1)
        assert current_decoder_outputs_repeated.shape[0] == topk_predictions.shape[0]


        # now we have both candidate scores and outputs, we need to prune paths

        candidate_scores = candidate_scores.reshape(batch_size, -1)
        # print(candidate_scores.shape)
        indices_to_keep = candidate_scores.topk(beam_size, dim=-1).indices
        pruned_scores = torch.stack([candidate_scores[i, indices_to_keep[i]] for i in range(indices_to_keep.shape[0])])

        assert (pruned_scores == candidate_scores).all()
        pruned_scores = pruned_scores.reshape(-1, 1)
        assert pruned_scores.shape[0] == beam_size * batch_size

        candidate_outputs = candidate_outputs.reshape(batch_size, -1, seq_len+1)
        # print(candidate_outputs.shape)
        pruned_outputs = torch.stack([candidate_outputs[i, indices_to_keep[i], :] for i in range(indices_to_keep.shape[0])])
        assert pruned_outputs.shape[0] == batch_size
        assert pruned_outputs.shape[1] == beam_size

        current_decoder_scores = pruned_scores
        current_decoder_outputs = pruned_outputs
        assert current_decoder_outputs.shape[1] <= beam_size
    # break
    return current_decoder_outputs, current_decoder_scores.reshape(batch_size, beam_size)

# %%
data_root = "../data/inference-test/"
ckp = "../lightning_logs/version_11/checkpoints/epoch=9.ckpt"
# %cd ..
# _, hparams = load_model("./lightning_logs/version_11/checkpoints/", "epoch=9.ckpt", root="../data/var-name/")
model = TransformerLightning.load_from_checkpoint(checkpoint_path="./lightning_logs/version_11/checkpoints/epoch=9.ckpt")
model.freeze()
root = "/media/devjeetroy/ss/testing-project/survey/internal/code_samples/processed/keycloak/variables/"
java_files = list(map(str, Path(root).glob("./**/*.java")))
java_files = [f for f in java_files if os.path.isfile(f)]
java_files.sort()

batch_size = 3
beam_size = 5

def create_dataset_from_hparams(filepath, hparams, vocabulary, variables=False):
    return C2SDataSet(
        filepath,
        hparams.max_contexts,
        vocabulary,
        hparams.subtoken_len,
        hparams.ast_len,
        hparams.target_len,
        shuffle=True,
        variable_only_filter=variables,
        line_cache=None,
    )

dataset = create_dataset_from_hparams(java_files[55], hparams, model.vocabulary, variables=True)
dataloader = DataLoader(dataset, batch_size=batch_size)
for batch in dataloader:
    break
# Out:
# line cache not found

# %%
labels, _ = batch
with torch.no_grad():
    outputs, scores = beam_search(model.cuda(), batch, beam_size=beam_size)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-2c74eec1cb2b> in <module>
#       1 labels, _ = batch
#       2 with torch.no_grad():
# ----> 3     outputs, scores = beam_search(model.cuda(), batch, beam_size=beam_size)
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in cuda(self, device)
#     302             Module: self
#     303         """
# --> 304         return self._apply(lambda t: t.cuda(device))
#     305
#     306     def cpu(self):
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     221                 # `with torch.no_grad():`
#     222                 with torch.no_grad():
# --> 223                     param_applied = fn(param)
#     224                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     225                 if should_use_set_data:
#
# ~/miniconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py in <lambda>(t)
#     302             Module: self
#     303         """
# --> 304         return self._apply(lambda t: t.cuda(device))
#     305
#     306     def cpu(self):
#
# RuntimeError: CUDA error: device-side assert triggered

# %%
# model, hparams = load_model(v_models, "epoch=9 new.ckpt")
# model = model.to(device)

# %%
labels = labels.tolist()
outputs = outputs.tolist()

for label, predictions in zip(labels, outputs):
    # print(labels)
    print(f"Label: {model.vocabulary.decode_target(label)}")
    for prediction in predictions:
        print(f"Prediction: {model.vocabulary.decode_target(prediction)}")
        print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1e808983a0c1> in <module>
#       1 labels = labels.tolist()
# ----> 2 outputs = outputs.tolist()
#       3
#       4 for label, predictions in zip(labels, outputs):
#       5     # print(labels)
#
# NameError: name 'outputs' is not defined

# %%
def run_inference(filepath, model, hparams, variables=False):
    dataset = create_dataset_from_hparams(filepath, hparams, model.vocabulary, variables=variables)
    dataloader = DataLoader(dataset, batch_size=1)

    for batch in dataloader:

#         batch = batch_to_cuda(batch)

        predictions, raw = model.predict(batch)
        predictions = predictions.tolist()
        
        labels = batch[0].tolist()

        prediction = model.vocabulary.decode_target(predictions[0])
        label = model.vocabulary.decode_target(labels[0])

        print(f"{label} -> {prediction}")

# model.as_type
for i  in range(len(java_files)):
    if "variables" not in java_files[i].split("/"):
        continue
    print(i)
    class_name = java_files[i].split("/")[-2:][0]
    # method_name = os.path.basename(java_files[i])
    class_method = f"{class_name}$"
    print(f"{class_method}")
    run_inference(java_files[i], model, hparams, variables=True)
# Out:
# 0
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# keycloak uri -> sb  uri
# keycloak uri -> uri  uri
# object array0  -> args  data
# 1
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder1
# 2
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# e  -> e e
# 3
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# 4
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  details
# 5
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# 6
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string0  -> template  xml
# keycloak uri -> builder  uri
# keycloak uri -> builder
# object array0  -> args  data
# 7
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# 8
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  uri
# integer0  -> expected  path
# 9
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> file name  file
# keycloak uri -> uri  uri
# 10
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# 11
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> sb  uri
# hash map0  -> params  headers
# string buffer0  -> request  body
# 12
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder1
# hash map0  -> params  properties
# string buffer0  -> req1  req1
# 13
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# keycloak uri -> uri  uri
# object array0  -> args  data
# 14
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> key
# u ri0  -> arg  arg
# object array0  -> args  data
# 15
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri  uri
# 16
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  uri
# 17
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# string buffer0  -> uri  uri
# 18
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> builder  details
# 19
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder1
# hash map0  -> params  data
# string buffer0  -> content ed
# 20
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder
# hash map0  -> context  properties
# string buffer0  -> request  body
# 21
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri builder  uri
# 22
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# string0  -> expected  xml
# 23
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# string0  -> path
# 24
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# keycloak uri -> uri  uri
# 25
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# u ri0  -> uri  uri
# 26
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri2  uri
# keycloak uri -> uri  uri
# object array0  -> args  data
# 27
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# 28
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# keycloak uri -> uri details1  details
# string0  -> path
# 29
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# u ri0  -> uri  uri
# string0  -> host  host
# 30
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  details
# keycloak uri -> uri  uri
# 31
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# 32
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  uri
# 33
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# keycloak uri -> uri  uri
# 34
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  uri
# 35
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  uri
# u ri0  -> uri  uri
# hash map0  -> base path
# 36
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# keycloak uri -> uri  uri
# u ri0  -> uri  uri
# u ri1  -> uri  uri
# 37
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# u ri1  -> uri  uri
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  uri
# u ri0  -> alt key uri
# hash map0  -> query  data
# 38
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  request
# hash map0  -> params  data
# 39
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# u ri1  -> uri  uri
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  uri
# u ri0  -> alt key uri
# hash map0  -> query  data
# 40
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# hash map0  -> base path  input
# 41
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# u ri1  -> request  uri
# keycloak uri -> uri  uri
# u ri0  -> alt key uri
# hash map0  -> headers  headers
# 42
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# object array0  -> a
# 43
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> foo  method
# keycloak uri -> uri  uri
# object array0  -> args  args
# 44
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  details
# e  -> e  e
# 45
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# e  -> e  ex
# 46
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder1
# e  -> e e
# hash map0  -> query params  headers
# 47
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# e  -> e e
# string buffer0  -> expected content  request
# 48
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# hash map0  -> query params  data
# e  -> e  e
# 49
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# e  -> e  e
# 50
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# e  -> e  e
# 51
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# matcher0  -> m  method
# keycloak uri -> builder  builder
# e  -> ex  ex
# 52
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# e  -> ex  ex
# 53
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# e  -> e  e
# 54
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# e  -> e e
# 55
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  details
# e  -> e  e
# hash map0  -> map  data
# 56
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder1
# e  -> e  e
# 57
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# keycloak uri -> uri details1  details
# e  -> e  e
# 58
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# e  -> e  e
# object array0  -> original  data
# 59
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  details
# e  -> ex  ex
# hash map0  -> map  properties
# 60
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder
# e  -> ex  ex
# object array0  -> a
# 61
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> builder  details
# object array0  -> args  data
# 62
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder
# 63
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# keycloak uri -> builder  builder
# 64
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# keycloak uri -> builder  builder
# 65
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  uri
# u ri0  -> uri  key
# 66
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> builder  builder
# 67
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  details
# e  -> e  ex
# 68
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# keycloak uri -> uri details1  uri
# u ri0  -> uri2  uri
# 69
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# e  -> ex  ex
# 70
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  details
# e  -> ex  ex
# 71
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# boolean0  -> result  result
# 72
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> details  details
# e  -> ex  ex
# 73
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# e  -> ex  ex
# 74
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# e  -> e  ex
# 75
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# integer0  -> a
# e  -> ex  ex
# 76
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# e  -> e  e
# 77
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# e  -> e  ex
# 78
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> details  details
# e  -> e  e
# 79
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  details
# e  -> e  e
# 80
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# e  -> e  e
# 81
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# integer0  -> a
# e  -> ex  ex
# 82
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  details
# e  -> e  ex
# 83
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> ws uri  uri
# u ri1  -> uri  uri
# object array0  -> args  args
# 84
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# 85
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# keycloak uri -> builder  details
# e  -> e  e
# object array0  -> original  data
# 86
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# e  -> e  ex
# 87
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri1  uri1
# keycloak uri -> builder
# object array0  -> args  data
# 88
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# keycloak uri -> uri details1  uri
# keycloak uri -> uri  uri
# object array0  -> input  input
# 89
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  details
# keycloak uri -> builder  builder
# e  -> e  ex
# object array0  -> a  data
# 90
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  details
# 91
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  details
# e  -> e  ex
# object array0  -> a  data
# 92
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder
# e  -> e  ex
# 93
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> foo uri  uri
# e  -> e  ex
# object array0  -> a  data
# 94
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# keycloak uri -> builder  builder1
# keycloak uri -> builder  builder
# keycloak uri -> uri details1  uri
# 95
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# e  -> e  ex
# 96
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# e  -> e  ex
# 97
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> column names  column
# keycloak uri -> builder  details
# e  -> e  ex
# 98
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  details
# e  -> e  e
# 99
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri  uri
# u ri0  -> uri  uri
# object array0  -> a  data
# 100
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# u ri0  -> ws uri  uri
# u ri1  -> uri  uri
# object array0  -> args  args
# 101
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# e  -> ex  ex
# u ri1  -> uri  uri
# keycloak uri -> uri details1  uri
# keycloak uri -> uri details1  uri
# u ri0  -> alt key uri
# hash map0  -> path  data
# 102
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# e  -> ex  ex
# keycloak uri -> builder  builder1
# keycloak uri -> uri details1  uri
# u ri0  -> alt key uri
# hash map0  -> properties  properties
# 103
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# keycloak uri -> builder  builder
# e  -> ex  ex
# hash map0  -> input  properties
# 104
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# u ri1  -> uri  uri
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# object array0  -> args  args
# 105
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# hash map0  -> input  data
# e  -> e  ex
# 106
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# e  -> e  ex
# keycloak uri -> uri details1  uri
# integer0  -> value  integer
# u ri0  -> uri  uri
# hash map0  -> result  data
# 107
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  details
# e  -> e  ex
# 108
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# e  -> e  ex
# 109
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# e  -> e  e
# hash map0  -> map  data
# 110
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# e  -> e  ex
# 111
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# hash map0  -> map  map
# e  -> e  e
# 112
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  uri
# 113
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri builder  uri
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# 114
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  details
# 115
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# keycloak uri -> builder  details
# 116
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# 117
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# 118
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder
# 119
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> parts  data
# keycloak uri -> uri details1  uri
# keycloak uri -> uri  uri
# u ri0  -> uri  uri
# 120
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# e  -> e  e
# 121
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> data  data
# e  -> e e
# 122
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# keycloak uri -> uri details1  uri
# u ri0  -> ws uri  uri
# e  -> e  ex
# 123
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder
# e  -> e  e
# 124
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# hash map0  -> properties  properties
# e  -> ex  ex
# 125
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# e  -> e  e
# 126
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> builder  details
# 127
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# hash map0  -> properties  properties
# e  -> ex  ex
# 128
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri  uri
# 129
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# e  -> e  ex
# 130
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder1
# e  -> e  e
# 131
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# keycloak uri -> uri details1  uri
# u ri0  -> uri2  case
# 132
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  uri
# u ri0  -> ws uri  uri
# u ri1  -> alt key uri
# 133
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# string array0  -> args  args
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# 134
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# u ri2  -> alt key uri
# u ri0  -> uri  uri
# u ri1  -> alt key uri
# 135
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# u ri0  -> uri  uri
# 136
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# e  -> e  e
# 137
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# u ri2  -> alt key uri
# u ri0  -> ws uri  uri
# u ri1  -> alt key uri
# 138
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# u ri1  -> alt key uri
# keycloak uri -> uri builder  uri
# u ri0  -> ws uri  uri
# hash map0  -> query  query
# 139
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# u ri0  -> uri  uri
# u ri1  -> uri  uri
# 140
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# boolean0  -> result  result
# 141
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder1
# string0  -> s ed
# 142
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# 143
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder
# 144
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder1
# 145
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# e  -> e  e
# hash map0  -> params  data
# 146
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# 147
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> alt key uri
# keycloak uri -> uri details1  uri
# 148
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri details1  uri
# u ri0  -> uri  uri
# 149
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# int0  -> port  port
# 150
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# e  -> e  e
# 151
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> builder  builder1
# 152
# KeycloakUriBuilder_ESTest.java$
# line cache not found
# keycloak uri -> uri  uri
# keycloak uri -> uri details1  uri
# u ri0  -> ws uri  uri
# 153
# MultivaluedHashMap_ESTest.java$
# line cache not found
# linked list0  -> d
# boolean0  -> result  data
# multivalued hash map1  -> aggregation  map
# multivalued hash map0  -> map2  integer
# integer0  -> integer  integer
# hash map0  -> root  root
# 154
# MultivaluedHashMap_ESTest.java$
# line cache not found
# linked list0  -> s4
# integer1  -> i3
# multivalued hash map0  -> map  map
# integer0  -> key1  key1
# hash map0  -> w
# 155
# MultivaluedHashMap_ESTest.java$
# line cache not found
# linked list0  -> integers  data
# integer1  -> integer  integer
# multivalued hash map0  -> map  map
# integer0  -> a
# hash map0  -> w
# 156
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> q  data
# list0  -> list  list
# linked list0  -> key
# 157
# MultivaluedHashMap_ESTest.java$
# line cache not found
# hash map1  -> f  integer
# e  -> ex  ex
# multivalued hash map1  -> map  map
# multivalued hash map0  -> o0  data
# hash map0  -> map  data
# object array0  -> v
# 158
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> q
# hash map0  -> f
# linked list0  -> list  list
# e  -> ex  ex
# 159
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> map  map
# e  -> e  ex
# 160
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> map  map
# integer0  -> c  integer
# e  -> e  ex
# 161
# MultivaluedHashMap_ESTest.java$
# line cache not found
# abstract map simple entry0 -> children  children
# linked list0  -> ce  ce
# e  -> ex  ex
# multivalued hash map0  -> queue  queue
# integer0  -> value1
# hash map0  -> f  data
# 162
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> map  data
# e  -> e  e
# 163
# MultivaluedHashMap_ESTest.java$
# line cache not found
# abstract map simple entry0 -> map  map
# e  -> ex  ex
# abstract map simple entry  -> map  map
# multivalued hash map1  -> queue  queue
# multivalued hash map0  -> identity  data
# hash map0  -> f  zero
# 164
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> f  q
# hash map0  -> f  zero
# linked list0  -> list
# e  -> e  e
# 165
# MultivaluedHashMap_ESTest.java$
# line cache not found
# linked list0  -> b
# e  -> e  e
# multivalued hash map0  -> q  testing
# integer0  -> key1  key1
# hash map0  -> root  root
# 166
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> q
# hash map0  -> f  f
# e  -> e  e
# 167
# MultivaluedHashMap_ESTest.java$
# line cache not found
# linked list0  -> cause
# e  -> ex  ex
# multivalued hash map1  -> e  exception
# multivalued hash map0  -> event  event
# linked list1  -> key1  key1
# hash map0  -> f
# 168
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> qd
# e  -> e  e
# 169
# MultivaluedHashMap_ESTest.java$
# line cache not found
# abstract map simple entry0 -> key
# linked list0  -> map  map
# e  -> ex  ex
# multivalued hash map0  -> error exception exception exception exception
# hash map0  -> map  map
# 170
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> integers  map
# integer0  -> key1  integer
# 171
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> q  case
# list array0  -> list  list
# hash map0  -> queue1  queue1
# list0  -> list2  list2
# 172
# MultivaluedHashMap_ESTest.java$
# line cache not found
# linked list0  -> d
# boolean0  -> result  data
# multivalued hash map1  -> f  case
# integer1  -> integer  integer
# multivalued hash map0  -> map2  one
# integer0  -> key1  key1
# hash map0  -> root  root
# 173
# MultivaluedHashMap_ESTest.java$
# line cache not found
# linked list0  -> s4
# boolean0  -> result  data
# multivalued hash map1  -> q  case
# multivalued hash map0  -> one  zero
# integer0  -> key1  integer
# hash map0  -> root  root
# 174
# MultivaluedHashMap_ESTest.java$
# line cache not found
# linked list0  -> s4
# boolean0  -> result  data
# multivalued hash map1  -> f  zero
# multivalued hash map0  -> three  zero
# integer0  -> key1  key1
# hash map0  -> w
# 175
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> f  f
# boolean0  -> result  data
# 176
# MultivaluedHashMap_ESTest.java$
# line cache not found
# boolean0  -> result  data
# multivalued hash map1  -> g  kernel
# multivalued hash map0  -> pf  zero
# integer0  -> v1  integer
# hash map0  -> w
# 177
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> map  map
# linked list0  -> list ized
# e  -> e  e
# 178
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> qd  qs
# e  -> e  ex
# 179
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> map  map
# hash map0  -> queue1  zero
# integer0  -> t2  data
# 180
# MultivaluedHashMap_ESTest.java$
# line cache not found
# multivalued hash map0  -> q  map
# linked list0  -> q
# 181
# UriUtils_ESTest.java$
# line cache not found
# ssl required0  -> ssl code  ssl
# e  -> e  ex
# 182
# UriUtils_ESTest.java$
# line cache not found
# ssl required0  -> ssl engine  ssl
# e  -> e  ex
# 183
# UriUtils_ESTest.java$
# line cache not found
# multivalued hash map0  -> map  map
# 184
# UriUtils_ESTest.java$
# line cache not found
# multivalued hash map0  -> map  map
# 185
# UriUtils_ESTest.java$
# line cache not found
# string0  -> result
# 186
# UriUtils_ESTest.java$
# line cache not found
# string0  -> result  url
# 187
# UriUtils_ESTest.java$
# line cache not found
# boolean0  -> b ed
# 188
# UriUtils_ESTest.java$
# line cache not found
# u ri0  -> uri  uri
# string0  -> result  url
# 189
# UriUtils_ESTest.java$
# line cache not found
# string0  -> path
# 190
# UriUtils_ESTest.java$
# line cache not found
# e  -> e e
# 191
# UriUtils_ESTest.java$
# line cache not found
# e  -> e  e
# 192
# UriUtils_ESTest.java$
# line cache not found
# e  -> e  e
# 193
# UriUtils_ESTest.java$
# line cache not found
# e  -> e  ex
# 194
# UriUtils_ESTest.java$
# line cache not found
# e  -> e  e
# 195
# UriUtils_ESTest.java$
# line cache not found
# string0  -> s
# 196
# UriUtils_ESTest.java$
# line cache not found
# string0  -> s ids
# 197
# UriUtils_ESTest.java$
# line cache not found
# ssl required0  -> ssl code  ssl
# 198
# UriUtils_ESTest.java$
# line cache not found
# ssl required0  -> ssl code  ssl
# 199
# UriUtils_ESTest.java$
# line cache not found
# ssl required0  -> ssl ssl ssl ssl ssl
# 200
# UriUtils_ESTest.java$
# line cache not found
# ssl required0  -> ssl  ssl
# e  -> e  ex
# 201
# UriUtils_ESTest.java$
# line cache not found
# multivalued hash map0  -> map  data
# 202
# UriUtils_ESTest.java$
# line cache not found
# multivalued hash map0  -> map  map
# 203
# UriUtils_ESTest.java$
# line cache not found
# u ri0  -> uri  uri
# string0  -> result  url
# 204
# UriUtils_ESTest.java$
# line cache not found
# string1  -> expected  name
# u ri0  -> uri  uri
# e  -> e  e
# string0  -> base uri  url
# 205
# UriUtils_ESTest.java$
# line cache not found
# e  -> e  e
# 206
# UriUtils_ESTest.java$
# line cache not found
# boolean0  -> b  interrupt
# 207
# UriUtils_ESTest.java$
# line cache not found
# uri utils0  -> uri  uri
# 208
# VerificationException_ESTest.java$
# line cache not found
# verification exception0  -> ex  ex
# mock throwable0  -> e  throwable
# verification exception1  -> e  ex
# 209
# VerificationException_ESTest.java$
# line cache not found
# verification exception0  -> e  e
# 210
# VerificationException_ESTest.java$
# line cache not found
# verification exception0  -> error  error
# verification exception1  -> e  exception
